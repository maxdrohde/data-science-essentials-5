# %%
import pandas as pd

# %%
# Load data
hospitals = pd.read_csv("data/Hospitals.csv")

# %%
# Filter data
hospitals.loc[hospitals["CITY"] == "NASHVILLE"].loc[hospitals["STATE"] == "TN"]
# Out:
#                  X             Y  OBJECTID        ID  \
# 545  -9.656923e+06  4.334433e+06       547   2237207
# 3449 -9.662661e+06  4.321662e+06      3452   2937203
# 3485 -9.667666e+06  4.325068e+06      3488   2437218
# 5429 -9.663292e+06  4.321786e+06      5439  12037203
# 5433 -9.663262e+06  4.323612e+06      5443   2137208
# 6289 -9.662755e+06  4.321820e+06      6300  17337203
# 6293 -9.662818e+06  4.319684e+06      6304  18037212
# 6661 -9.663004e+06  4.320144e+06      6674  13537212
# 6774 -9.662894e+06  4.321982e+06      6787  13137203
# 6777 -9.667487e+06  4.318442e+06      6790   2337205
# 6786 -9.653837e+06  4.311137e+06      6799   2037211
# 6808 -9.663534e+06  4.321798e+06      6821  11937203
# 6813 -9.662773e+06  4.320018e+06      6826  15837232
#
#                                                NAME  \
# 545                  TRISTAR SKYLINE MEDICAL CENTER
# 3449          SELECT SPECIALTY HOSPITAL - NASHVILLE
# 3485                           CURAHEALTH NASHVILLE
# ...

# %%
df["CITY"] == "NASHVILLE"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7591    False
# 7592    False
# 7593    False
# 7594    False
# 7595    False
# Name: CITY, Length: 7596, dtype: bool
